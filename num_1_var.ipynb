# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# 1.1. [Load Data](#toc1_1_)
# 1.2. [Basic Summary Statistics](#toc1_2_)
# 1.3. [Data Visualization](#toc1_3_)
# 1.3.1. [Line Plot](#toc1_3_1_)
# 1.3.2. [Distribution plot](#toc1_3_2_)
# 1.4. [Assumptions Check](#toc1_4_)
# 1.4.1. [Modality](#toc1_4_1_)
# 1.4.2. [Normality](#toc1_4_2_)
# 1.4.3. [Normality With Transformation](#toc1_4_3_)
# 1.4.4. [Robustness](#toc1_4_4_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=true
# 	anchor=true
# 	flat=true
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %%
import numpy as np
import ipywidgets as widgets
import openpyxl as xl
import pandas as pd
from matplotlib import pyplot as plt
import scipy.stats as stats
import seaborn as sns
import pingouin as pg

from statsmodels.stats.stattools import medcouple

from dist_test import check_multimodality, check_normality, recommand_normality_test
from robust_test import recommand_outliers_test, outliers_by_method

# force reload modules
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1.1. <a id='toc1_1_'></a>[Load Data](#toc0_)

# %%
sheet_names= xl.load_workbook("data/data_num.xlsx").sheetnames
def load_data(file_path="data/data_cat.xlsx", sheet=sheet_names[0]):
    df = pd.read_excel(file_path, sheet_name=sheet)
    return df.head()
widgets.interact(
    load_data,
    file_path=widgets.fixed("data/data_num.xlsx"),
    sheet=widgets.Dropdown(options=sheet_names, value=sheet_names[0])
    );
# Out:
# interactive(children=(Dropdown(description='sheet', options=('conductivity',), value='conductivity'), Output()…

# %%
df = pd.read_excel("data/data_num.xlsx")
df.head()
# Out:
#                Date   LC2A     MP2     MP1     MC
# 0  22/10/2025 18:00  721.0  870.75  845.12  850.2
# 1  22/10/2025 20:00  650.0  760.20  848.10  889.8
# 2  22/10/2025 22:30  644.0  638.40  749.00  682.3
# 3  23/10/2025 01:00  636.0  552.70  741.00  658.2
# 4  23/10/2025 04:00  649.0  607.42  755.40  670.2

# %%
cols = ["Date", "LC2A", "MP2", "MP1", "MC"]

data = (df[cols]
    .melt(id_vars="Date", var_name="group", value_name="value")
    .dropna()
    .sort_values(by="Date")
    .drop(columns=["Date", "group"])
)
data.head(6)
# Out:
#      value
# 0   721.00
# 69  850.20
# 46  845.12
# 23  870.75
# 70  889.80
# 24  760.20

# %% [markdown]
# ## 1.2. <a id='toc1_2_'></a>[Basic Summary Statistics](#toc0_)

# %%
X = data.values.flatten()
# n = 1_000
# X = np.random.normal(0, 1, n)
# X= np.random.lognormal (1, 1, n)
# X = X.flatten()

# %%
data = pd.Series(X)
n = len(data)
stats_summary:pd.DataFrame = data.describe(percentiles=[.025, 0.25, 0.5, 0.75, .975])
stats_summary.loc["CV"] = np.nan if stats_summary['std'] == 0 else stats_summary['std'] / stats_summary['mean']
stats_summary['#NaN'] = X[np.isnan(X)].sum()
# add skewness and kurtisis to stats_summary
stats_summary.loc["skewness"] = data.skew()
stats_summary.loc["kurtosis"] = data.kurtosis()
stats_summary.round(3)
# Out:
# count        88.000
# mean        711.331
# std          75.379
# min         535.000
# 2.5%        566.000
# 25%         657.650
# 50%         718.500
# 75%         760.438
# 97.5%       849.833
# max         889.800
# CV            0.106
# #NaN          0.000
# skewness     -0.102
# kurtosis     -0.289
# dtype: float64

# %% [markdown]
# ## 1.3. <a id='toc1_3_'></a>[Data Visualization](#toc0_)

# %% [markdown]
# ### 1.3.1. <a id='toc1_3_1_'></a>[Line Plot](#toc0_)

# %%
plt.style.use("seaborn-v0_8-dark")
data.plot(kind='line', style='--', linewidth=0.5, title='Plot of the data', figsize=(10, 4));
plt.scatter(range(len(data)), data, s=20, alpha=0.8, marker='x')
plt.grid()

# %% [markdown]
# ### 1.3.2. <a id='toc1_3_2_'></a>[Distribution plot](#toc0_)

# %%
def adaptive_boxplot_stats(data, adjusted=False):
    """
    Creates an Adjusted Boxplot for skewed distributions (Hubert & Vandervieren, 2008).
    """

    X = np.array(data)
    X = X[~np.isnan(X)]  # Remove NaNs

    if not adjusted or (
        float(abs(stats.skew(X))) < 1 and float(abs(stats.kurtosis(X))) < 1
    ):
        mc = 0
    else:
        mc = medcouple(X)

    q1, q3 = np.percentile(X, [25, 75])
    iqr = q3 - q1

    # Calculate whiskers based on medcouple sign
    if mc >= 0:
        lower_whisker = q1 - 1.5 * np.exp(-4 * mc) * iqr
        upper_whisker = q3 + 1.5 * np.exp(3.5 * mc) * iqr
    else:
        lower_whisker = q1 - 1.5 * np.exp(-3.5 * mc) * iqr
        upper_whisker = q3 + 1.5 * np.exp(4 * mc) * iqr

    # Identify outliers
    outliers = X[(X < lower_whisker) | (X > upper_whisker)]

    # Plotting
    # We use a standard boxplot but manually override the whiskers/fliers if needed,
    # or simply plot the components manually for clarity.
    # Here is a manual construction to ensure the adjusted whiskers are respected.

    # Filter X within whiskers for the box and whiskers plot
    mask_within = (X >= lower_whisker) & (X <= upper_whisker)
    adjacent_values = X[mask_within]

    if len(adjacent_values) > 0:
        whisker_min = np.min(adjacent_values)
        whisker_max = np.max(adjacent_values)
    else:
        whisker_min = q1
        whisker_max = q3

    bpstats = {
        "med": np.median(X),
        "mean": np.mean(X),
        "q1": q1,
        "q3": q3,
        "whislo": whisker_min,
        "whishi": whisker_max,
        "fliers": outliers,
        "medcouple": mc,
        "label": "Data",
    }
    return bpstats

# %%
def plot_univariate_num(X, hist_stat="count", adjusted=False, transform="boxcox", **kwrgs):
    plt.style.use("seaborn-v0_8-dark")
    fig, axes = plt.subplot_mosaic(
        [["ax1", "ax3"], ["ax2", "ax3"]],
        figsize=(10, 4),
        height_ratios=(0.8, 0.2),
    )
    ax1, ax2, ax3 = axes["ax1"], axes["ax2"], axes["ax3"]
    if transform == "boxcox":
        X = stats.boxcox(
            X + 1e-6
        )[
            0
        ]  # Box-Cox transformation requires positive data,calcul done with optimal lambda using MLE method
    elif transform == "boxcox_pearson":
        X = stats.boxcox(
            X + 1e-6, lmbda=stats.boxcox_normmax(X + 1e-6, method="pearsonr")
        )  # Box-Cox with optimal lambda using Pearson's method
    elif transform == "yeojohnson":
        X = stats.yeojohnson(
            X
        )[
            0
        ]  # Yeo-Johnson can handle zero and negative values, and use optimal lambda using MLE method
    elif transform == "yeojohnson_pearson":
        X = stats.yeojohnson(
            X, lmbda=stats.yeojohnson_normmax(X)
        )  # Yeo-Johnson with optimal lambda using Pearson's method
    elif transform == "log":
        X = np.log(X + 1e-6)  # Log transformation requires positive data
    else:
        pass  # No transformation
    
    sns.histplot(X, kde=True, bins=kwrgs.get('bins', 'auto'), stat=hist_stat, ax=ax1)
    ax1.grid(True)
    # add legend using mean and median with no trait
    mean_x, median_x = np.mean(X), np.median(X)
    ax1.text(
        0.95,
        0.95,
        f"Mean: {mean_x:.2f}\nMedian: {median_x:.2f}",
        horizontalalignment="right",
        verticalalignment="top",
        transform=ax1.transAxes,
        fontsize=8,
        bbox=dict(facecolor="white", alpha=0.5),
    )
    # _, n_outliers = adaptive_boxplot_stats(X, ax=ax2, adjusted=adjusted)
    # ax2.set_xticks([])
    bpstats = adaptive_boxplot_stats(X, adjusted=adjusted)
    mc = bpstats["medcouple"]
    n_outliers = len(bpstats["fliers"])
    ax2.bxp(
        [bpstats],
        showfliers=True,
        orientation="horizontal",
        showmeans=True,
        widths=0.4,
        flierprops={"markersize": 4},
    )
    if mc != 0:
        ax2.set_xlabel(
            f"Adjusted Boxplot (medcouple={mc:.3f}, n_outliers={n_outliers})",
            fontsize=10,
        )
    else:
        ax2.set_xlabel(f"n_outliers={n_outliers}", fontsize=10)
    pg.qqplot(X, ax=ax3, s=10, dist=kwrgs.get('dist', 'norm'))
    ax3.set_title("Henry test:Q-Q plot")
    n = len(X)
    test = recommand_normality_test(n, percent_outlier=100*n_outliers/n)
    method = test["alias"]
    verdict = "Normal" if check_normality(X, method) else "Not Normal"
    ax1.set_title(f"Distribution of data ({test['test']}:{verdict})")
    plt.tight_layout()
    plt.show()
    global n_outliers_transf
    n_outliers_transf = n_outliers


widgets.interact(
    plot_univariate_num,
    X=widgets.fixed(data),
    bins=widgets.Dropdown(options=['auto', 'fd', 'rice', 'sturges', 'sqrt'], value='auto'),
    hist_stat=widgets.Dropdown(
        options=["count", "probability", "density"],
        value="count",
        description="Hist Stat:",
    ),
    adjusted=widgets.Checkbox(value=True, description="Adjusted Boxplot"),
    transform=widgets.fixed("none"),
);
# Out:
# interactive(children=(Dropdown(description='Hist Stat:', options=('count', 'probability', 'density'), value='c…

# %% [markdown]
# ## 1.4. <a id='toc1_4_'></a>[Assumptions Check](#toc0_)

# %% [markdown]
# ### 1.4.1. <a id='toc1_4_1_'></a>[Modality](#toc0_)

# %%
# %autoreload

is_unimodal, k_modes = check_multimodality(data)
if is_unimodal:
    print("Data is unimodal.")
else:
	print(f"Data is multimodal with {k_modes} modes.")
# Out:
# ======== GAUSSIAN MIXTURE MODEL (BIC COMPARISON) ========
# --------------------------------------------------
# Components      BIC                    AIC
# --------------------------------------------------
# 1            1018.45 ← BEST         1013.49 ← BEST
# 2            1031.08                1018.69
# 3            1040.35                1020.53
# 4            1050.92                1023.66
# 5            1059.27                1024.58
# --------------------------------------------------
# ✓ Data appear UNIMODAL (1 component)
# ...
#
# Data is unimodal.

# %% [markdown]
# ### 1.4.2. <a id='toc1_4_2_'></a>[Normality](#toc0_)

# %%
print(f"{'Data Normality':.^100}")
normality_test_result = []
for r in sorted([0, 5, 11, n_outliers_transf/len(data)*100]):
    test = recommand_normality_test(n, percent_outlier=r)
    method = test["alias"]
    verdict = check_normality(data, method)
    normality_test_result.append(verdict)
    print(f"Considering {r:.1f}% of Ouliers: \t{test['alias']:<15}: {verdict}")
    
pg.qqplot(data, s=10, alpha=0.5)
if any(normality_test_result):
    plt.gca().set_title("Distribution seems Normal");
else:
    plt.gca().set_title("Distribution doesn't seem Normal");
# Out:
# ...........................................Data Normality...........................................
# Considering 0.0% of Ouliers: 	shapiro        : True
# Considering 0.0% of Ouliers: 	shapiro        : True
# Considering 5.0% of Ouliers: 	normaltest     : True
# Considering 11.0% of Ouliers: 	anderson       : True

# %% [markdown]
# ### 1.4.3. <a id='toc1_4_3_'></a>[Normality With Transformation](#toc0_)

# %%
# n_outliers_transf = 0

if not any(normality_test_result):
    print("No need for power transformation")
else:
    print(f"{'Transformed Data Normality':.^100}")
    for transform in ["boxcox", "yeojohnson", "log"]:
        if transform == "boxcox":
            X_transf = stats.boxcox(X.copy() + 1e-6)[
                0
            ]  # Box-Cox transformation requires positive data
        elif transform == "yeojohnson":
            X_transf = stats.yeojohnson(X.copy())[
                0
            ]  # Yeo-Johnson can handle zero and negative values
        elif transform == "log":
            X_transf = np.log(X.copy() + 1e-6)
        n = len(X_transf)
        r = n_outliers_transf / n
        test = recommand_normality_test(n, percent_outlier=r)
        method = test["alias"]
        verdict = check_normality(X_transf, method)
        print(f"Transformation {transform:<11}==> {test['alias']:<1}: {verdict}")
        
    widgets.interact(
					plot_univariate_num,
					X=widgets.fixed(data),
					hist_stat=widgets.Dropdown(
						options=["count", "probability", "density"],
						value="count",
						description="Hist Stat:",
					),
					adjusted=widgets.Checkbox(value=True, description="Adjusted Boxplot"),
					transform=widgets.Dropdown(
						options=[
							"boxcox",
							"boxcox_pearson",
							"yeojohnson",
							"yeojohnson_pearson",
							"log",
							"none"
						],
						value="boxcox",
						description="Transform:",
					),
				);
# Out:
# .....................................Transformed Data Normality.....................................
# Transformation boxcox     ==> shapiro: True
# Transformation yeojohnson ==> shapiro: True
# Transformation log        ==> shapiro: True
# interactive(children=(Dropdown(description='Hist Stat:', options=('count', 'probability', 'density'), value='c…

# %% [markdown]
# ### 1.4.4. <a id='toc1_4_4_'></a>[Robustness](#toc0_)

# %%
print(f"{'Outliers':.^100}")
is_normal = normality_test_result[0]
if not any(normality_test_result) == 0 or all(normality_test_result):
    method_robustness = recommand_outliers_test(
        X, normality=is_normal, unimodal=is_unimodal
    )
    robustness_result = outliers_by_method(X, method_robustness[0])
else:
    for i in range(6):
        method_robustness = recommand_outliers_test(
            X, normality=is_normal, unimodal=is_unimodal
        )
        robustness_result = outliers_by_method(X, method_robustness[0])
        r = 100 * float(robustness_result["ratio_outliers"])
        test = recommand_normality_test(n, percent_outlier=r)["alias"]
        if check_normality(X, method=test) == is_normal:
            break
        else:
            is_normal = not is_normal
print("Recommanded outliers test methods:", method_robustness)
print(f"Results of the outliers detection using {method_robustness[0]}:")
print(f"\t\t{robustness_result['n_outliers']} outliers detected,\t percentage: {robustness_result['ratio_outliers']:.3%}")
# Out:
# ..............................................Outliers..............................................
# Recommanded outliers test methods: ('z-score', 'IQR')
# Results of the outliers detection using z-score:
# 		4 outliers detected,	 percentage: 4.545%

# %%
from robust_test import univar_outliers_auto_threshold	

robustness_result = univar_outliers_auto_threshold(X, use_mad=True)
r = float(robustness_result['ratio_outliers'])

test = recommand_normality_test(n, percent_outlier=r)
method = test["alias"]
verdict = check_normality(X, method)
if verdict == is_normal:
    print(f"Normality: {verdict} (Tested with {test['test']})\nOutliers ratio: {r:.2%}")
else:
    print("explore adjusted boxplot")
# Out:
# Normality: True (Tested with Shapiro-Wilk)
# Outliers ratio: 0.00%

# %% [markdown]
# # Reporting

# %%
def summary_stats(X):
    na_counts = X[np.isnan(X)].sum()
    data = pd.Series(X)
    n = len(data)
    stats_summary:pd.DataFrame = data.describe(percentiles=[.025, 0.25, 0.5, 0.75, .975])
    stats_summary.loc["skewness"] = data.skew()
    stats_summary.loc["kurtosis"] = data.kurtosis()
    stats_summary.loc["CV"] = np.nan if stats_summary['std'] == 0 else stats_summary['std'] / stats_summary['mean']
    stats_summary['#NaN'] = na_counts
    return stats_summary.to_frame(name='stat')
	# add skewness and kurtisis to stats_summary
 
def explore_disrtibution(data):
    widgets.interact(
    plot_univariate_num,
    X=widgets.fixed(data),
    bins=widgets.Dropdown(options=['auto', 'fd', 'rice', 'sturges', 'sqrt'], value='auto'),
    dist=widgets.Dropdown(
		options=['norm', 'expon', 'uniform', 'lognorm', 'gamma', 'beta', 't', 'chi2', 'f'],
		value='norm',
		description='Distribution:'),
    hist_stat=widgets.Dropdown(
        options=["count", "probability", "density"],
        value="count",
        description="Hist Stat:",
    ),
    adjusted=widgets.Checkbox(value=True, description="Adjusted Boxplot"),
    transform=widgets.Dropdown(
						options=[
							"boxcox",
							"boxcox_pearson",
							"yeojohnson",
							"yeojohnson_pearson",
							"log",
							"none"
						],
						value="none",
						description="Transform:",
					),
);
    
def auto_normality_and_robestness_test(X):
    robustness_result = univar_outliers_auto_threshold(X, use_mad=True)
    n = len(X)
    r = float(robustness_result['ratio_outliers'])

    test = recommand_normality_test(n, percent_outlier=r)
    method = test["alias"]
    verdict = check_normality(X, method)
    if verdict == is_normal:
        print(f"Normality: {verdict} (Tested with {test['test']})\nOutliers ratio: {r:.2%}")
    else:
        print("explore adjusted boxplot")
def report_eda(X):
    na_counts = X[np.isnan(X)].sum()
    data = pd.Series(X)
    data = pd.Series(X)
    print('=========================================STATITICS SUMMARY=============================================')
    summary = summary_stats(data).round(3)
    display(summary.T)
    data.plot(kind='line', style='--', linewidth=0.5, title='Plot of the data', figsize=(10, 4));
    plt.scatter(range(len(data)), data, s=20, alpha=0.8, marker='x')
    plt.grid()
    
    print('======================================MODALITY ANALYSIS SUMMARY=======================================')
    is_unimodal, k_modes = check_multimodality(data)
    if is_unimodal:
        print("Data is unimodal.")
    else:
        print(f"Data is multimodal with {k_modes} modes.")
    print('======================================DISTRIBUTION EXPLORATION=======================================')
    explore_disrtibution(data)
    print('=========================================DISTRIBUTION VERDIC=============================================')
    auto_normality_and_robestness_test(data)
    
report_eda(X)
# Out:
# =========================================STATITICS SUMMARY=============================================
#       count     mean     std    min   2.5%     25%    50%      75%    97.5%  \
# stat   88.0  711.331  75.379  535.0  566.0  657.65  718.5  760.438  849.833
#
#         max  skewness  kurtosis     CV  #NaN
# stat  889.8    -0.102    -0.289  0.106   0.0
# ======================================MODALITY ANALYSIS SUMMARY=======================================
#
# ======== GAUSSIAN MIXTURE MODEL (BIC COMPARISON) ========
# --------------------------------------------------
# Components      BIC                    AIC
# --------------------------------------------------
# 1            1018.45 ← BEST         1013.49 ← BEST
# 2            1031.08                1018.69
# 3            1040.35                1020.53
# 4            1050.92                1023.66
# 5            1059.27                1024.58
# --------------------------------------------------
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 stats.distribution_summary(X_transf)
#
# AttributeError: module 'scipy.stats' has no attribute 'distribution_summary'
